# %% [markdown]
# # **Correlations**

# %% [markdown]
# ***Imports***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
import Python_Code.Scripts as sc
import Python_Code.Reference as ref

# %%
#New Mexico
nm07 = pd.read_csv('./data/clean_nm07.csv')
nm17 = pd.read_csv('./data/clean_nm17.csv')

#Nebraska
ne07 = pd.read_csv('./data/clean_ne07.csv')
ne17 = pd.read_csv('./data/clean_ne17.csv')

# %% [markdown]
# # **Feature Section**

# %% [markdown]
# # *Correlated Dataframes*

# %% [markdown]
# ***Correlation Plots***

# %%
def corr_df(fullname, dataset):
    """Creates a dataframe on .corr(), used for unit categories."""
    fullname_df = pd.DataFrame()
    for feature in fullname['Table 1']:
        try:
            fullname_df[feature] = dataset[feature]
        except:
            continue
    fullname_df['CAT_ELIG']=dataset['CAT_ELIG'].astype("float64")
    return fullname_df

# %%
# 2007 Datasets
Unit_Demo= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\07_DataDict\Unit_Demo.csv')
Unit_Assets= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\07_DataDict\Unit_Assets.csv')
Unit_Inc= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\07_DataDict\Unit_Inc.csv')
Unit_ExDed= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\07_DataDict\Unit_ExDed.csv')
Pers_Char= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\07_DataDict\Pers_Char.csv')
Pers_Inc= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\07_DataDict\Pers_Inc.csv')
# 2017 Datasets
Unit_Demo= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\17_DataDict\Unit_Demo.csv')
Unit_Assets= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\17_DataDict\Unit_Assets.csv')
Unit_Inc= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\17_DataDict\Unit_Inc.csv')
Unit_ExDed= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\17_DataDict\Unit_ExDed.csv')
Pers_Char= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\17_DataDict\Pers_Char.csv')
Pers_Inc= pd.read_csv(r'C:\Users\aneel\Desktop\SNAP\Data\17_DataDict\Pers_Inc.csv')

# %%
plt.figure(figsize= (25,10))
plt.suptitle("2007 New Mexico Correlations (Descending)",fontsize=15)
plt.subplot(2,3,1)
sns.heatmap(sc.corr_df(ref.Unit_demo, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True,xticklabels=[])
plt.title("Unit Demographics")
plt.yticks(rotation=0)
plt.subplot(2,3,2)
sns.heatmap(sc.corr_df(ref.Unit_assets, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Assets")
plt.yticks(rotation=0)
plt.subplot(2,3,3)
sns.heatmap(sc.corr_df(ref.Unit_ExDed, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Expenses/Deductions")
plt.yticks(rotation=0)
plt.subplot(2,3,4)
sns.heatmap(sc.corr_df(ref.Unit_Inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Income")
plt.yticks(rotation=0)
plt.subplot(2,3,5)
sns.heatmap(sc.corr_numcol(ref.Pers_Char, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Charcteristics")
plt.yticks(rotation=0)
plt.subplot(2,3,6)
sns.heatmap(sc.corr_numcol(ref.Pers_Inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Income")
plt.yticks(rotation=0)
plt.savefig('./images/correlations/corrD_nm07.png');

# %%
plt.figure(figsize= (25,10))
plt.suptitle("2007 New Mexico Correlations (Ascending)",fontsize=15)
plt.subplot(2,3,1)
sns.heatmap(sc.corr_df(ref.Unit_demo, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True,xticklabels=[])
plt.title("Unit Demographics")
plt.yticks(rotation=0)
plt.subplot(2,3,2)
sns.heatmap(sc.corr_df(ref.Unit_assets, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Assets")
plt.yticks(rotation=0)
plt.subplot(2,3,3)
sns.heatmap(sc.corr_df(ref.Unit_ExDed, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Expenses/Deductions")
plt.yticks(rotation=0)
plt.subplot(2,3,4)
sns.heatmap(sc.corr_df(ref.Unit_Inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Income")
plt.yticks(rotation=0)
plt.subplot(2,3,5)
sns.heatmap(sc.corr_numcol(ref.Pers_Char, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Charcteristics")
plt.yticks(rotation=0)
plt.subplot(2,3,6)
sns.heatmap(sc.corr_numcol(ref.Pers_Inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Income")
plt.yticks(rotation=0)
plt.savefig('./images/correlations/corrD_nm07.png');

# %%
plt.figure(figsize= (25,10))
plt.suptitle("2007 Nebraska Correlations(Descending)",fontsize=15)
plt.subplot(2,3,1)
sns.heatmap(sc.corr_df(ref.Unit_demo, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True,xticklabels=[])
plt.title("Unit Demographics")
plt.yticks(rotation=0)
plt.subplot(2,3,2)
sns.heatmap(sc.corr_df(ref.Unit_assets, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Assets")
plt.yticks(rotation=0)
plt.subplot(2,3,3)
sns.heatmap(sc.corr_df(ref.Unit_ExDed, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Expenses/Deductions")
plt.yticks(rotation=0)
plt.subplot(2,3,4)
sns.heatmap(sc.corr_df(ref.Unit_Inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Income")
plt.yticks(rotation=0)
plt.subplot(2,3,5)
sns.heatmap(sc.corr_numcol(ref.Pers_Char, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Charcteristics")
plt.yticks(rotation=0)
plt.subplot(2,3,6)
sns.heatmap(sc.corr_numcol(ref.Pers_Inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Income")
plt.yticks(rotation=0)
plt.savefig('./images/correlations/corrD_ne07.png');

# %%
plt.figure(figsize= (25,10))
plt.suptitle("2007 Nebraska Correlations(Descending)",fontsize=15)
plt.subplot(2,3,1)
sns.heatmap(sc.corr_df(ref.Unit_demo, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True,xticklabels=[])
plt.title("Unit Demographics")
plt.yticks(rotation=0)
plt.subplot(2,3,2)
sns.heatmap(sc.corr_df(ref.Unit_assets, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Assets")
plt.yticks(rotation=0)
plt.subplot(2,3,3)
sns.heatmap(sc.corr_df(ref.Unit_ExDed, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Expenses/Deductions")
plt.yticks(rotation=0)
plt.subplot(2,3,4)
sns.heatmap(sc.corr_df(ref.Unit_Inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Unit Income")
plt.yticks(rotation=0)
plt.subplot(2,3,5)
sns.heatmap(sc.corr_numcol(ref.Pers_Char, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Charcteristics")
plt.yticks(rotation=0)
plt.subplot(2,3,6)
sns.heatmap(sc.corr_numcol(ref.Pers_Inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5),vmin=-1,cmap='viridis',annot=True)
plt.title("Personal Income")
plt.yticks(rotation=0)
plt.savefig('./images/correlations/corrD_ne07.png');

# %%
sc.plot_features_hist('FSTANF','unit_tanf',"Countable TANF Income for Head of Household")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sc.plot_features_hist('FSTANF','unit_tanf',"Countable TANF Income for Head of Household")
#
# File ~\Desktop\SNAP\Python_Code\Scripts.py:125, in plot_features_hist(column, img_name, description)
#     123         ax.xaxis.set_label_coords(0.15, 1.05)
#     124         idx +=1
# --> 125 plt.savefig("./images/ind_features/" + str(img_name) + ".png")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:996, in savefig(*args, **kwargs)
#     993 @_copy_docstring_and_deprecators(Figure.savefig)
#     994 def savefig(*args, **kwargs):
#     995     fig = gcf()
# --> 996     res = fig.savefig(*args, **kwargs)
#     997     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     998     return res
#
# ...

# %%
set1 = list(pd.DataFrame(sc.corr_df(ref.Unit_demo, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set2 = list(pd.DataFrame(sc.corr_df(ref.Unit_assets, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set3 = list(pd.DataFrame(sc.corr_df(ref.Unit_ExDed, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set4 = list(pd.DataFrame(sc.corr_df(ref.Unit_Inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set5 = list(pd.DataFrame(sc.corr_df(ref.Pers_Char, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set6 = list(pd.DataFrame(sc.corr_df(ref.Pers_Inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)

set7 = list(pd.DataFrame(sc.corr_df(ref.Unit_demo, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set8 = list(pd.DataFrame(sc.corr_df(ref.Unit_assets, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set9 = list(pd.DataFrame(sc.corr_df(ref.Unit_ExDed, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set10 = list(pd.DataFrame(sc.corr_df(ref.Unit_Inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set11 = list(pd.DataFrame(sc.corr_df(ref.Pers_Char, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set12 = list(pd.DataFrame(sc.corr_df(ref.Pers_Inc, nm07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)

corr_features = set1 + set2 + set3 + set4 + set5 + set6 + set7 + set8 + set9 + set10 + set11

# %%
set1 = list(pd.DataFrame(sc.corr_df(ref.Unit_demo, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set2 = list(pd.DataFrame(sc.corr_df(ref.Unit_assets, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set3 = list(pd.DataFrame(sc.corr_df(ref.Unit_ExDed, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set4 = list(pd.DataFrame(sc.corr_df(ref.Unit_Inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set5 = list(pd.DataFrame(sc.corr_df(ref.Pers_Char, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)
set6 = list(pd.DataFrame(sc.corr_df(ref.Pers_Inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=False).head(5)).T.columns)

set7 = list(pd.DataFrame(sc.corr_df(ref.Unit_demo, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set8 = list(pd.DataFrame(sc.corr_df(ref.Unit_assets, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set9 = list(pd.DataFrame(sc.corr_df(ref.Unit_ExDed, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set10 = list(pd.DataFrame(sc.corr_df(ref.Unit_Inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set11 = list(pd.DataFrame(sc.corr_df(ref.Pers_Char, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)
set12 = list(pd.DataFrame(sc.corr_df(ref.Pers_Inc, ne07).corr()[['CAT_ELIG']].sort_values(by = 'CAT_ELIG',ascending=True).head(5)).T.columns)

corr_features = set1 + set2 + set3 + set4 + set5 + set6 + set7 + set8 + set9 + set10 + set11
corr_features=set(corr_features)
corr_features.remove('CAT_ELIG')

# %%
print(f'There are {len(corr_features)} features in corr_features:\n')
corr_features
# Out:
# There are 24 features in corr_features:
# {'CERTHHSZ',
#  'FSERNDE2',
#  'FSERNDED',
#  'FSGRINC',
#  'FSNDISCA',
#  'FSNELDER',
#  'FSNK5T17',
#  'FSNONCIT',
#  'FSOTHUN',
#  'FSSLTDE2',
#  'FSSLTDED',
#  'FSSLTEXP',
#  'FSSTDDE2',
#  'FSTOTDE2',
#  'FSTOTDED',
#  'FSUNEMP',
#  'FSUSIZE',
#  'FSVEHAST',
#  'FSWAGES',
#  'FSWCOMP',
#  'LIQRESOR',
#  'RAWERND',
#  'REALPROP',
#  'VEHICLEA'}

# %%
#Note missing 'FSGA','FDIS','FSSI','FSASSET','FSEARN',WRK_POOR','SHELDED','TANF_IND','TPOV',FSTANF

# %% [markdown]
# # *Final Dataset*

# %%
corr_features=list(corr_features)
pd.DataFrame(corr_features,columns=['Table 1']).to_csv("./data/corr_features.csv")

# %%
df1 = sc.final(corr_features,nm07)
df2 = sc.final(corr_features,nm17)
df3 = sc.final(corr_features,ne07)
df4 = sc.final(corr_features,ne17)

# %%
df = pd.concat([df1,df2,df3,df4])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3904 entries, 0 to 893
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FSUNEMP   3904 non-null   float64
#  1   FSNK5T17  3904 non-null   float64
#  2   LIQRESOR  2940 non-null   float64
#  3   FSSLTDE2  3904 non-null   float64
#  4   FSSLTDED  3904 non-null   float64
#  5   FSOTHUN   3904 non-null   float64
#  6   FSGRINC   3904 non-null   float64
#  7   FSUSIZE   3904 non-null   float64
#  8   FSTOTDE2  3904 non-null   float64
#  9   FSSTDDE2  3904 non-null   float64
#  10  FSNONCIT  3904 non-null   float64
#  11  RAWERND   3904 non-null   float64
#  12  FSTOTDED  3904 non-null   float64
#  13  REALPROP  2046 non-null   float64
#  14  FSERNDED  3904 non-null   float64
#  15  FSERNDE2  3904 non-null   float64
#  16  FSNELDER  3904 non-null   float64
#  17  FSNDISCA  3904 non-null   float64
#  18  FSWAGES   3904 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# FSUNEMP        0
# FSNK5T17       0
# LIQRESOR     964
# FSSLTDE2       0
# FSSLTDED       0
# FSOTHUN        0
# FSGRINC        0
# FSUSIZE        0
# FSTOTDE2       0
# FSSTDDE2       0
# FSNONCIT       0
# RAWERND        0
# FSTOTDED       0
# REALPROP    1858
# FSERNDED       0
# FSERNDE2       0
# FSNELDER       0
# FSNDISCA       0
# FSWAGES        0
# FSWCOMP        0
# FSSLTEXP       0
# CERTHHSZ       0
# CAT_ELIG       0
# FSVEHAST    2219
# VEHICLEA    3113
# dtype: int64

# %%
df['VEHICLEA']=df['VEHICLEA'].fillna(1)

# %%
df.isnull().sum()
# Out:
# FSUNEMP        0
# FSNK5T17       0
# LIQRESOR     964
# FSSLTDE2       0
# FSSLTDED       0
# FSOTHUN        0
# FSGRINC        0
# FSUSIZE        0
# FSTOTDE2       0
# FSSTDDE2       0
# FSNONCIT       0
# RAWERND        0
# FSTOTDED       0
# REALPROP    1858
# FSERNDED       0
# FSERNDE2       0
# FSNELDER       0
# FSNDISCA       0
# FSWAGES        0
# FSWCOMP        0
# FSSLTEXP       0
# CERTHHSZ       0
# CAT_ELIG       0
# FSVEHAST    2219
# VEHICLEA       0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.to_csv('./data/final.csv',index=None)
